# %%
from sklearn.neighbors import KNeighborsClassifier
import pandas as pd
import math
from opencage.geocoder import OpenCageGeocode
from clean import clean, stats
import json
import numpy as np

# %%
df = pd.read_csv('data/profile_data.csv')

# %%
df = clean(df)
# Out:
# -----------------
# CLEANING DATA
# ...
# FOUND 56783 ENTRIES
# REMOVED 0 EMPTY ENTRIES
# REMOVED 0 DUPLICATED ENTRIES

# %%
stats(df)
# Out:
# -----------------
# CALCULATING STATS
# ...
# FOUND 56783 ENTRIES
# 56335 ENTRIES HAVE AGE DATA (99.2%)
# 19773 ENTRIES HAVE COLLEGE DATA (34.8%)
# 14456 ENTRIES HAVE CITY DATA (25.5%)
# 14540 ENTRIES HAVE JOB DATA (25.6%)
# 10153 ENTRIES HAVE GENDER DATA (17.9%)
# 55631 ENTRIES HAVE DISTANCE DATA (98.0%)
# 42256 ENTRIES HAVE DETAIL DATA (74.4%)
# 15078 ENTRIES HAVE ANTHEM DATA (26.6%)
# ...
# AVERAGE AGE IN DATA SET: 24
# NUMBER OF UNIQUE COLLEGES: 7793
# NUMBER OF UNIQUE JOBS: 9530
# NUMBER OF UNIQUE CITIES: 2793

# %%
df.city.isna().sum()
# Out:
# 42327

# %%
def fill_city(series,city_list,KNN_model):
    if type(series.city)==float and ~np.isnan(series.distance):
        try:
            city = np.random.choice(city_list[series.distance],1, replace=True)[0]
        except:
            if ~np.isnan(series.distance):
                city = KNN_model.predict(np.array([[series.distance]]))[0]
            else:
                city = float('nan')
    else:
        city = series.city
    return city

# %%
# def fill_missing_cities(data):
#     '''
#     Use Numpy Random Choice to fill in missing cities based on others in same distance
#     '''
#     num = data.city.isna().sum()
#     print("FOUND {} MISSING CITY VALUES".format(num))
#     filtered = data[-data.city.isna()].copy()
#     filtered = filtered[-filtered.distance.isna()]
#     city_list = {}
#     for each in filtered.distance.unique():
#         city_list[each] = list(filtered[filtered.distance == each].city)

#     #KNN for remaining values:
#     X = np.array(list(filtered.distance)).reshape(-1,1)
#     y = np.array(list(filtered.city))
#     KNN_City = KNeighborsClassifier(n_neighbors=10).fit(X,y)
#     print("KNN TEST")
#     print(KNN_City.predict([[1981.0]]))
    
#     data.city = data.apply(lambda x: fill_city(x,city_list,KNN_City), axis =1)
#     new_num = data.city.isna().sum()
#     print("{} MISSING CITY VALUES REMAIN".format(new_num))
    
#     return data

# %%
def fill_missing_cities(data):
    '''
    Use Numpy Random Choice to fill in missing cities based on others in same distance
    '''
    print("-----------------")
    print("FILLING MISSING CITY VALUES")
    num = data.city.isna().sum()
    print("FOUND {} MISSING VALUES".format(num))
    filtered = data[-data.city.isna()].copy()
    filtered = filtered[-filtered.distance.isna()]
    city_list = {}
    for each in filtered.distance.unique():
        city_list[each] = list(filtered[filtered.distance == each].city)

    #KNN for remaining values:
    X = np.array(list(filtered.distance)).reshape(-1,1)
    y = np.array(list(filtered.city))
    KNN_City = KNeighborsClassifier(n_neighbors=10).fit(X,y)
    
    data.city = data.apply(lambda x: fill_city(x,city_list,KNN_City), axis =1)
    new_num = data.city.isna().sum()
    print("{} MISSING CITY VALUES REMAIN ({}%)".format(new_num,round(new_num/len(data),2)))
    
    return data.cities

# %%
cit = fill_missing_cities(df.city)
# Out:
# -----------------
# FILLING MISSING CITY VALUES
# FOUND 42327 MISSING VALUES
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-12-dfbd49b9fb2c> in <module>
# ----> 1 cit = fill_missing_cities(df.city)
#
# <ipython-input-10-11a824263038> in fill_missing_cities(cities)
#       8     print("FOUND {} MISSING VALUES".format(num))
#       9     filtered = cities[-cities.isna()].copy()
# ---> 10     filtered = filtered[-filtered.distance.isna()]
#      11     city_list = {}
#      12     for each in filtered.distance.unique():
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5065             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5066                 return self[name]
# -> 5067             return object.__getattribute__(self, name)
#    5068
#    5069     def __setattr__(self, name, value):
#
# AttributeError: 'Series' object has no attribute 'distance'

# %%
df = fill_missing_cities(df)
# Out:
# FOUND 919 MISSING CITY VALUES
# KNN TEST
# ['Tallahassee']
# 919 MISSING CITY VALUES REMAIN

# %%
df[df.city.isna()]
# Out:
#                name   age                                            college  \
# 5            Marina  21.0                                                NaN
# 48            Clara   NaN                                                UBA
# 61          Shereen  29.0                                                NaN
# 142           P a k  26.0                                                NaN
# 152           Sofia   NaN                                                NaN
# 183            Iren  25.0                                                NaN
# 245           Linda  24.0                                                NaN
# 482    Texas barbie  19.0                   Texas A&M University-San Antonio
# 516          Olivia   NaN                                                NaN
# 645            Leen  35.0                                  College of Europe
# 650         Marlina  26.0                                                NaN
# 712             Kim  26.0                                                NaN
# 749           Cathy  27.0                   New York Institute of Technology
# 753           Yajna   NaN                                                NaN
# 779        Sunshine  37.0                                                NaN
# 786          Elaine  24.0  Embry-Riddle Aeronautical University, Daytona ...
# 806         Aislinn  25.0                                                NaN
# 823             Liz  24.0                                                NaN
# 852             Ola  20.0                                                NaN
# 910         Monifah  24.0                     University of Nebraska-Lincoln
# 957        Mystique  23.0                                        Some School
# 968            Kate  24.0                                                NaN
# 984           Mizzo  30.0                                                NaN
# 1015          Robin  23.0                                                NaN
# 1038          Sarah  23.0                                                NaN
# 1059            Ivy   NaN                                                NaN
# 1062          Mandy  37.0                            University of Cambridge
# 1199        Jasmine   NaN                                                NaN
# 1322       Vanerich  21.0                                                NaN
# 1390        Scarlet   NaN                                                NaN
# ...             ...   ...                                                ...
# 55023           Amy   NaN                                               香港大学
# 55042        Emilia  22.0                                  Monash University
# 55050       Chabeli  22.0                                                NaN
# 55089        Athena   NaN       Limkokwing University of Creative Technology
# 55094        Nickki  23.0                                                NaN
# 55132           Tay  19.0                                                NaN
# 55173     Monserrat  19.0                                                NaN
# 55230           Kim  21.0                                             上海戏剧学院
# 55303        Bethan  26.0                                                NaN
# 55370      Meredith  25.0                 University of Southern Mississippi
# 55418         Perla  23.0                                                NaN
# 55829       Aengela   NaN                                                NaN
# 55844          Thea  31.0                                                NaN
# 55866          Anna  25.0                                                NaN
# 56022    Jacqueline  27.0                                                NaN
# 56072          Ella  28.0                        Pacifica Graduate Institute
# 56094          Ryah   NaN                                                NaN
# 56189         Margo  30.0                                                NaN
# 56198        Maarja  20.0                                                NaN
# 56277       Brianne   NaN                         University of Pennsylvania
# 56300          Mira  20.0                                                NaN
# 56456        Taylor  26.0                                                NaN
# 56530         Chloe   NaN                                                NaN
# 56547          Star   NaN                                                NaN
# 56627          Elli  25.0                                                NaN
# 56696           Mel  21.0                                                NaN
# 56737         Helen  25.0                                                NaN
# 56742         Alada  25.0                                                NaN
# 56755        Judith  25.0          Universidad Internacional de las Américas
# 56772          Nina  23.0                                                NaN
#
#                                                      job city       gender  \
# 5                                                    NaN  NaN          NaN
# 48                                                   NaN  NaN          NaN
# 61                                                   NaN  NaN          NaN
# 142         MD , Hostel owner , Travel blogger , WWOOFer  NaN        Woman
# 152                                                  NaN  NaN          NaN
# 183                                                  NaN  NaN          NaN
# 245                                                  NaN  NaN          NaN
# 482                 Nursing at University Medical Center  NaN          NaN
# 516                                                  NaN  NaN          NaN
# 645                                                  NaN  NaN          NaN
# 650                                                  NaN  NaN          NaN
# 712                                                  NaN  NaN          NaN
# 749                            Full Time Nursing Student  NaN          NaN
# 753             Yajnamusic at Rising Phoenix Music Group  NaN        Woman
# 779                                                  NaN  NaN          NaN
# 786                 Aviation Structural Mechanic at Navy  NaN          NaN
# 806                                                  NaN  NaN          NaN
# 823                                                  NaN  NaN          NaN
# 852                                                  NaN  NaN          NaN
# 910                                                  NaN  NaN          NaN
# 957                                                  Gov  NaN          NaN
# 968                                                  NaN  NaN          NaN
# 984                                                  NaN  NaN          NaN
# 1015                                        Entrepreneur  NaN          NaN
# 1038                                                 NaN  NaN          NaN
# 1059                                                 NaN  NaN          NaN
# 1062   Oxbridge lecturer and Educational Consultant S...  NaN          NaN
# 1199                                                 NaN  NaN          NaN
# 1322                                                 NaN  NaN          NaN
# 1390                                                 NaN  NaN          NaN
# ...                                                  ...  ...          ...
# 55023                                        Female hero  NaN        Woman
# 55042                                     Lab Technitian  NaN          NaN
# 55050                                                NaN  NaN        Woman
# 55089                          Marketing & Communication  NaN          NaN
# 55094                                Executive Assistant  NaN          NaN
# 55132                                     Aspiring Model  NaN        Woman
# 55173                                                NaN  NaN          NaN
# 55230                                                NaN  NaN          NaN
# 55303                                            Teacher  NaN          NaN
# 55370      Colorguard Director at Petal High School Band  NaN          NaN
# 55418                                                NaN  NaN          NaN
# 55829                                                NaN  NaN          NaN
# 55844                                                NaN  NaN          NaN
# 55866                                                NaN  NaN          NaN
# 56022                                                NaN  NaN          NaN
# 56072                                National Geographic  NaN          NaN
# 56094                                                NaN  NaN        Woman
# 56189                                                NaN  NaN          NaN
# 56198                                                NaN  NaN          NaN
# 56277                                   Registered Nurse  NaN          NaN
# 56300                                                NaN  NaN          NaN
# 56456                                                NaN  NaN          NaN
# 56530                                                NaN  NaN  Trans Woman
# 56547                                                NaN  NaN          NaN
# 56627                                                NaN  NaN          NaN
# 56696                                             SFXMUA  NaN          NaN
# 56737                                            Athlete  NaN          NaN
# 56742                                                NaN  NaN        Woman
# 56755                                                NaN  NaN        Woman
# 56772                                                NaN  NaN          NaN
#
#        distance                                            details  \
# 5           NaN  Hi my name is Marina. I am Mexican and Italian...
# 48          NaN             Trabajo 🍷 Abogada 🎓 De la Patagonia 📍
# 61          NaN                         Instagram: ShereenAgbarie
# 142         NaN  Live with passion and Lead with power. \r\nLif...
# 152         NaN  Im down in HOOK UP! \r\nIf you want to hook up...
# 183         NaN                                                NaN
# 245         NaN                             ➡️ Instagram: nulinda
# 482         NaN  I’m Whiskey In a Tea Cup Kinda Latina 💕 😘 Regi...
# 516         NaN                " Every person is a new world " 🌍
# 645         NaN                                                NaN
# 650         NaN                                                NaN
# 712         NaN  This is just my attempt and some social intera...
# 749         NaN  Living, forgiving, learning, conquering, heali...
# 753         NaN  IG : Yajnamusic 🧡 Follow me 🧡 Lover of life. L...
# 779         NaN  Dolphins are so intelligent that, within a few...
# 786         NaN                          IG:b.elaineiflowers61420
# 806         NaN  PO-TAY-TOES\r\nBoil em, mash em, stick em in a...
# 823         NaN  98% chance Ill delete this again. \r\nIG- Damn...
# 852         NaN  Better hit me up on insta \r\nIg: napiorkowska...
# 910         NaN                  IG 📷 : Mo_Yvonne\r\nSC: Moyvonne
# 957         NaN  IG:Whaateversyd\r\nSC:Whaateversyd \r\nI love ...
# 968         NaN                                       Inst: w_._e
# 984         NaN                                   Chilled vibes 😎
# 1015        NaN                                                NaN
# 1038        NaN  I’m just tryna find someone with a home gym 😭 ...
# 1059        NaN                                                NaN
# 1062        NaN  Possibly the only Cambridge lecturer with an o...
# 1199        NaN  I am a fun-loving, sophisticated woman who lov...
# 1322        NaN                Bilingual 🥰 Latina from New York 🗽
# 1390        NaN  I'm cultured in that I like imported wine and ...
# ...         ...                                                ...
# 55023       NaN     I always believe that tomorrow will be better
# 55042       NaN  5, 3” and in need of a stepladder\nI’ve been i...
# 55050       NaN                Looking for my future ex-husband 💭
# 55089       NaN  I’m easily attached to fictional movie charact...
# 55094       NaN            insta; nickkimauceri\nsnap; nickkimauc
# 55132       NaN  My name is Taylor but Tay is fine. I’m in scho...
# 55173       NaN  I am as bad as the worst, but, thank God, I am...
# 55230       NaN  🤩 In Fl now, looking to meet new ppl !\n\nInst...
# 55303       NaN  British\nAll you need to lure me into your car...
# 55370       NaN  history & dance & travel\n\nbeer enthusiast, v...
# 55418       NaN  Hey hi hello! Just trying to meet and get to k...
# 55829       NaN  Fuck Off you dirty perverted asshole. I'm begg...
# 55844       NaN  Everytime I heard the boys talked about a beau...
# 55866       NaN  🇦🇺 girl Looking for someone with good banter t...
# 56022       NaN  Ig - @Kingjac__\n\nI’m honestly just here to w...
# 56072       NaN  Looking for a first husband to feed to my pet ...
# 56094       NaN            I love my music 🎶 guys who can dance 😳
# 56189       NaN  Saint-Petersburg - Turin 🇷🇺 🇮🇹 🇺🇸 IG - margoza...
# 56198       NaN          want to share my hand sanitizer with you
# 56277       NaN  Hello there 👋🏻 So I’m back to Tinder to give i...
# 56300       NaN                                                NaN
# 56456       NaN                                      @taysagraves
# 56530       NaN  manic pixie trans girl\n\nif you’re not down, ...
# 56547       NaN  #Workaholic \nSo we match we both wait 5 to 7 ...
# 56627       NaN                    Meh\n\ninstagram: ellijohannaa
# 56696       NaN  insta: melvenusxo 🦋 💫 🌈 💓 ♉️ Beach bum 🐠 🐟 🐬 n...
# 56737       NaN                           Insta - @Helenhousby1 🌸
# 56742       NaN                                                NaN
# 56755       NaN  Made in Costa Rica 🇨🇷 Wine and fashion lover. ...
# 56772       NaN  Medical student.\n\nIf anything good came out ...
#
#                                                   anthem  \
# 5                                                    NaN
# 48                                                   NaN
# 61                                                   NaN
# 142                                                  NaN
# 152                                                  NaN
# 183                                                  NaN
# 245                                                  NaN
# 482                           ('Wanted', 'Hunter Hayes')
# 516                                                  NaN
# 645                                                  NaN
# 650                                                  NaN
# 712                                                  NaN
# 749                                                  NaN
# 753                          ('Last Heartbeat', 'Yajna')
# 779                                                  NaN
# 786                   ('Nice To Meet Ya', 'Niall Horan')
# 806                                                  NaN
# 823                                                  NaN
# 852                                                  NaN
# 910      ('LOYAL (feat. Drake)', 'PARTYNEXTDOOR, Drake')
# 957                        ('Best Friend', 'Young Thug')
# 968                                                  NaN
# 984                                                  NaN
# 1015                                                 NaN
# 1038                                                 NaN
# 1059                                                 NaN
# 1062                                                 NaN
# 1199                 ('We Have Time', 'Sabrina Claudio')
# 1322                      ('Sin Filtro', 'Romeo Santos')
# 1390                                                 NaN
# ...                                                  ...
# 55023                                                NaN
# 55042  ('Under The Sun (with J. Cole & Lute feat. DaB...
# 55050                                                NaN
# 55089                                                NaN
# 55094                                                NaN
# 55132                                                NaN
# 55173                     ('Pretty Face', 'King Staccz')
# 55230  ('Kaleidoscope Love - Kaytranada Edition', 'Al...
# 55303                                                NaN
# 55370  ('Built To Roam - Audiotree Live Version', 'Sh...
# 55418                             ('Airplane', 'j-hope')
# 55829                                                NaN
# 55844                        ('3:00 AM', 'Finding Hope')
# 55866                                                NaN
# 56022                        ('Heartless', 'The Weeknd')
# 56072                                                NaN
# 56094                        ('New Light', 'John Mayer')
# 56189      ("I Don't Want to Miss a Thing", 'Aerosmith')
# 56198            ('Little Talks', 'Of Monsters and Men')
# 56277  ('I Will Follow You Into The Dark', 'Death Cab...
# 56300                                                NaN
# 56456                                                NaN
# 56530                                                NaN
# 56547                                                NaN
# 56627                                                NaN
# 56696                                                NaN
# 56737                                                NaN
# 56742                                                NaN
# 56755                                                NaN
# 56772                                                NaN
#
#                                         profile_pic_urls
# 5      ['https://images-ssl.gotinder.com/5e90cd4a98d4...
# 48     ['https://images-ssl.gotinder.com/58b89a9048fe...
# 61     ['https://images-ssl.gotinder.com/5e78e9a6724b...
# 142    ['https://images-ssl.gotinder.com/5d228b35d4df...
# 152    ['https://images-ssl.gotinder.com/5e90dee25cb7...
# 183    ['https://images-ssl.gotinder.com/5e726c39066b...
# 245    ['https://images-ssl.gotinder.com/5cd063b910f3...
# 482    ['https://images-ssl.gotinder.com/5d572b1ceb31...
# 516    ['https://images-ssl.gotinder.com/5e85af1a76e5...
# 645    ['https://images-ssl.gotinder.com/52f2d1fffd79...
# 650    ['https://images-ssl.gotinder.com/5e6b0603fb37...
# 712    ['https://images-ssl.gotinder.com/5bf7666c330b...
# 749    ['https://images-ssl.gotinder.com/5d5098c0484c...
# 753    ['https://images-ssl.gotinder.com/5e2c69e99853...
# 779    ['https://images-ssl.gotinder.com/5d7b506afc3c...
# 786    ['https://images-ssl.gotinder.com/5e3cdeab8586...
# 806    ['https://images-ssl.gotinder.com/5c3224afc54e...
# 823    ['https://images-ssl.gotinder.com/5e7c499bdfb4...
# 852    ['https://images-ssl.gotinder.com/5e9096a6deea...
# 910    ['https://images-ssl.gotinder.com/5c22e4f7ab67...
# 957    ['https://images-ssl.gotinder.com/5be8f6a5c1f0...
# 968    ['https://images-ssl.gotinder.com/5e88de2176e5...
# 984    ['https://images-ssl.gotinder.com/5e7de6fa066b...
# 1015   ['https://images-ssl.gotinder.com/5c95a68d26ac...
# 1038   ['https://images-ssl.gotinder.com/5e509e74641b...
# 1059   ['https://images-ssl.gotinder.com/5e8af16310b9...
# 1062   ['https://images-ssl.gotinder.com/5d7e78a6e78f...
# 1199   ['https://images-ssl.gotinder.com/5b21a8715c34...
# 1322   ['https://images-ssl.gotinder.com/5616e9cceff3...
# 1390   ['https://images-ssl.gotinder.com/5e90f239ca5e...
# ...                                                  ...
# 55023  ['https://images-ssl.gotinder.com/5e8d8cf06efe...
# 55042  ['https://images-ssl.gotinder.com/5e8f441195f2...
# 55050  ['https://images-ssl.gotinder.com/5e88d9f836dd...
# 55089  ['https://images-ssl.gotinder.com/5e5f4915422b...
# 55094  ['https://images-ssl.gotinder.com/5e8ea9b54ae7...
# 55132  ['https://images-ssl.gotinder.com/5dcc9950b2c0...
# 55173  ['https://images-ssl.gotinder.com/5e289053fa8b...
# 55230  ['https://images-ssl.gotinder.com/5d8cdaf37b8e...
# 55303  ['https://images-ssl.gotinder.com/5e8762e638ab...
# 55370  ['https://images-ssl.gotinder.com/55fcd7653708...
# 55418  ['https://images-ssl.gotinder.com/5b8cd661ef62...
# 55829  ['https://images-ssl.gotinder.com/5e6f36eae209...
# 55844  ['https://images-ssl.gotinder.com/598564adb33b...
# 55866  ['https://images-ssl.gotinder.com/5c0a290e1a9e...
# 56022  ['https://images-ssl.gotinder.com/54bde502fef8...
# 56072  ['https://images-ssl.gotinder.com/5e8fe2a398d4...
# 56094  ['https://images-ssl.gotinder.com/5e7c7a3d90e4...
# 56189  ['https://images-ssl.gotinder.com/550b0b8b6351...
# 56198  ['https://images-ssl.gotinder.com/5e0e1e7c9be6...
# 56277  ['https://images-ssl.gotinder.com/5e8d05cd3cbc...
# 56300  ['https://images-ssl.gotinder.com/5e781fb590e4...
# 56456  ['https://images-ssl.gotinder.com/5e584c3cbcfe...
# 56530  ['https://images-ssl.gotinder.com/5e5179a38d8b...
# 56547  ['https://images-ssl.gotinder.com/5c1b72fde479...
# 56627  ['https://images-ssl.gotinder.com/52d10766b51a...
# 56696  ['https://images-ssl.gotinder.com/59bf40f3a360...
# 56737  ['https://images-ssl.gotinder.com/527e58975fe9...
# 56742  ['https://images-ssl.gotinder.com/5e8c29324aed...
# 56755  ['https://images-ssl.gotinder.com/5e8f4965ccf0...
# 56772  ['https://images-ssl.gotinder.com/5e85eb46477c...
#
# [919 rows x 10 columns]

# %%
df.city.isna().sum()
# Out:
# 42327

# %%
df = df[-df.city.isna()]

# %%
df = df[-df.distance.isna()]

# %%
X = np.array(list(df.distance)).reshape(-1,1)
y = np.array(list(df.city)).reshape(-1,1)

# %%
KNN_City = KNeighborsClassifier(n_neighbors=10).fit(X,y)
# Out:
# /Users/matthewhwang/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().

# %%
KNN_City.predict(np.array([[1981.0]]))[0]
# Out:
# 'Tallahassee'

# %%
import plotly.express as px
# Out:
# /Users/matthewhwang/anaconda3/lib/python3.7/site-packages/dask/config.py:168: YAMLLoadWarning:
#
# calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#
# /Users/matthewhwang/anaconda3/lib/python3.7/site-packages/distributed/config.py:20: YAMLLoadWarning:
#
# calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.

# %%
eighteen = list(df[df.distance==18.0].city)

# %%
bootstrap_list = []

# %%
bootstrap = np.random.choice(eighteen, size=1000, replace=True)

# %%
test = pd.DataFrame(bootstrap)

# %%
test.columns = ['city']

# %%
filtered = df[-df.city.isna()].copy()
filtered = filtered[-filtered.distance.isna()]
city_list = {}

# %%
city_list[1981.0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-123-6d956cbcf32e> in <module>
# ----> 1 city_list[1981.0]
#
# KeyError: 1981.0

# %%
for each in filtered.distance.unique():
    city_list[each] = list(filtered[filtered.distance == each].city)

# %%
def fill_city(series,city_list,KNN_model):
    if type(series.city)==float:
        try:
            city = np.random.choice(city_list[series.distance],1, replace=True)[0]
        except:
            city = KNN_model.predict(np.array([[series.distance]]))[0]
    else:
        city = series.city
    return city

# %%
for _,row in df.iterrows():
    row.city = fill_city(row)

# %%
df.city = df.apply(lambda x: fill_city(x,city_list,KNN_City), axis =1)

# %%
df.city.isna().sum()
# Out:
# 0

# %%
df.head(10)
# Out:
#         name   age                                   college  \
# 0     Gianna  19.0                                       NaN
# 2   Britanny  19.0                         Santa Ana College
# 3      Kayla  28.0                                    School
# 4   Kimberly  18.0  California State University, Los Angeles
# 6    Natalia  23.0                                       NaN
# 7     Ariana  18.0                       Stockton University
# 8     Marion  18.0                                       NaN
# 9      София  18.0                                       NaN
# 10      Jena  29.0                     Pasadena City College
# 11     Zorry  18.0                                       NaN
#
#                     job           city gender  distance  \
# 0                   NaN       Barnegat    NaN    2430.0
# 2   Boys and girls club   Garden Grove    NaN      19.0
# 3                   NaN    Los Angeles  Woman      18.0
# 4                   NaN         Cudahy  Woman      15.0
# 6                   NaN  Monterey Park    NaN       9.0
# 7                   NaN      Maplewood    NaN    2425.0
# 8                   NaN     Manchester    NaN    5272.0
# 9                   NaN   Новороссийск    NaN    6772.0
# 10                  NaN    Los Angeles  Woman      15.0
# 11                  NaN       Erkelenz  Woman    5644.0
#
#                                               details  \
# 0                  ig- _.giaannaa_\r\nsc- gianna8378
# 2   Get to know me ☺️ Never been to Disneyland 😅 S...
# 3   I am a creative person that loves simple, inno...
# 4                            Just for fun\r\nI’m 5’2
# 6   Using Tinder often & I love it, but I post mos...
# 7   I’m funny, I can make you laugh I guess:)\r\nA...
# 8                                   his(panic) 🇲🇽 🇳🇴
# 9   Ласка одной львицы лучше, чем гарем дешевых гиен
# 10  Oh, how much I do not like the type of men who...
# 11       what are some fun hobbies aside of eating ?
#
#                                                anthem  \
# 0   ('Slide (Remix) (feat. Pop Smoke, A Boogie Wit...
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                           ('Wet Dreamz', 'J. Cole')
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
#
#                                      profile_pic_urls
# 0   ['https://images-ssl.gotinder.com/5dc0814dfc09...
# 2   ['https://images-ssl.gotinder.com/5cace3ad9b7a...
# 3   ['https://images-ssl.gotinder.com/5e90cb67da1c...
# 4   ['https://images-ssl.gotinder.com/5e0ffa53349f...
# 6   ['https://images-ssl.gotinder.com/5e90cebbda1c...
# 7   ['https://images-ssl.gotinder.com/5de1e5f4b4d4...
# 8   ['https://images-ssl.gotinder.com/5e05edcd2c19...
# 9   ['https://images-ssl.gotinder.com/5e4c009210ba...
# 10  ['https://images-ssl.gotinder.com/5e90cea1cb59...
# 11  ['https://images-ssl.gotinder.com/5e1509538fca...
